# %% [markdown]
# <a href="https://colab.research.google.com/github/raziarasheed/assignment4-001-6/blob/main/04_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("00_count_nums")

def count_numbers():
    count_dict = {}

    while True:
        user_input = input("Enter a number (or 'Exit' to quit): ")
        if user_input.lower() == "exit":
            break
        elif user_input.isdigit():
            num = int(user_input)
            count_dict[num] = count_dict.get(num, 0) + 1
        else:
            print("Invalid input. Please enter a number or 'Exit'.")

    return count_dict

def display_counts(count_dict):
    print("\nNumber Counts:")
    for key, value in count_dict.items():
        print(f"{key} appears {value} time(s)")

if __name__ == "__main__":
    count_dict = count_numbers()
    display_counts(count_dict)
# Out:
# 00_count_nums
# Enter a number (or 'Exit' to quit): 3
# Enter a number (or 'Exit' to quit): 4
# Enter a number (or 'Exit' to quit): 5
# Enter a number (or 'Exit' to quit): 3
# Enter a number (or 'Exit' to quit): 5
# Enter a number (or 'Exit' to quit): 6
# Enter a number (or 'Exit' to quit): 7
# Enter a number (or 'Exit' to quit): exit
#
# Number Counts:
# 3 appears 2 time(s)
# 4 appears 1 time(s)
# 5 appears 2 time(s)
# 6 appears 1 time(s)
# 7 appears 1 time(s)

# %%
print("01_phonebook")
def add_contact(phonebook):
    name = input("Enter contact name: ")
    phone = input("Enter contact phone number: ")
    email = input("Enter contact email: ")
    if name in phonebook:
        print(f"{name} already exists in the phonebook.")
    else:
        phonebook[name] = {"phone": phone, "email": email}
        print(f"{name} added to the phonebook.")
def search_contact(phonebook):
    name = input("Enter contact name to search: ")
    if name in phonebook:
        contact = phonebook[name]
        print(f"Name: {name}")
        print(f"Phone: {contact['phone']}")
        print(f"Email: {contact['email']}")
    else:
        print(f"{name} not found in the phonebook.")

def delete_contact(phonebook):
    name = input("Enter contact name to delete: ")
    if name in phonebook:
        del phonebook[name]
        print(f"{name} deleted from the phonebook.")
    else:
        print(f"{name} not found in the phonebook.")

def display_contact(phonebook):
    print("\n Phonebook Contacts List:")
    for name, contact in phonebook.items():
        print(f"Name: {name}")
        print(f"Phone: {contact['phone']}")
        print(f"Email: {contact['email']}")
    else:
      print("Phonebook is empty.")

if __name__ == "__main__":
    phonebook = {}

    while True:
        print("\nPhonebook Menu:")
        print("1. Add Contact")
        print("2. Search Contact")
        print("3. Delete Contact")
        print("4. Display Contacts")
        print("5. Exit")
        choice = input("Enter your choice (1-5): ")

        if choice == "1":
            add_contact(phonebook)
        elif choice == "2":
         search_contact(phonebook)
        elif choice == "3":
         delete_contact(phonebook)
        elif choice == "4":
         display_contact(phonebook)
        elif choice == "5":
         print("Exiting Phonebook. Goodbye!")
         break
        else:
         print("Invalid choice. Please enter a number between 1 and 5.")
# Out:
# 01_phonebook
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice (1-5): 1
# Enter contact name: rabia
# Enter contact phone number: 03152954225
# Enter contact email: rasheedrazia33@gmail.com
# rabia added to the phonebook.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice (1-5): 2
# Enter contact name to search: rabia
# Name: rabia
# Phone: 03152954225
# Email: rasheedrazia33@gmail.com
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice (1-5): 3
# Enter contact name to delete: farah
# farah not found in the phonebook.
#
# Phonebook Menu:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice (1-5): 4
#
#  Phonebook Contacts List:
# Name: rabia
# Phone: 03152954225
# Email: rasheedrazia33@gmail.com
# ...

# %%
print("02_pop_up_shop")

def calculate_total_cost():
    fruits_price = {
        "apple": 5.0,
        "mango": 15.0,
        "kiwi": 8.0,
        "pear": 12.0,
        "banana": 10.0,
        "orange": 6.0,
    }

    total_cost = 0

    for fruit, price in fruits_price.items():
        while True:
            try:
                quantity = int(input(f"How many {fruit}s do you want? "))
                if quantity < 0:
                    print("Invalid input. Please enter a non-negative number.")
                    continue
                total_cost += price * quantity
                break
            except ValueError:
                print("Invalid input. Please enter a valid number.")

    print(f"\nYour total cost is: ${total_cost:.2f}")

if __name__ == "__main__":
    calculate_total_cost()
# Out:
# 02_pop_up_shop
# How many apples do you want? 2
# How many mangos do you want? 3
# How many kiwis do you want? 4
# How many pears do you want? 4
# How many bananas do you want? 6
# How many oranges do you want? 7
#
# Your total cost is: $237.00

# %%
import hashlib

print("03_powerful_passwords")

def hash_passward(passward):
  return hashlib.sha256(passward.encode()).hexdigest()
stored_logins ={
  "user@example.com": hash_passward("password123"),
  "admin@example.com": hash_passward("adminpass2")


}

def login(login,passward):
  if email in stored_logins:
    return stored_logins[email] == hash_passward(password)
  else:
    return False

if __name__ == "__main__":
  email = input("Enter your email: ")
  password = input("Enter your password: ")
  if login(email,password):
    print("Login successful")
  else:
    print("Login failed")
# Out:
# 03_powerful_passwords
# Enter your email: user@example.com
# Enter your password: password123
# Login successful
